# %%
# import the necessary libraries
import numpy as np
import pandas as pd

# for visuals
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load and read data file
Store_Sales = pd.read_csv(r'C:\Users\USER\Downloads\Python Projects-20230802T122045Z-001\Python Projects\Stores.csv')
Store_Sales
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %% [markdown]
# ## Data Understanding
# --- Dataframe shape,head and tail,dt types and data description

# %%
# DataFrame shape
Store_Sales.shape
# Out:
# (896, 5)

# %%
Store_Sales.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
Store_Sales.tail()
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340

# %%
Store_Sales.dtypes
# Out:
# Store ID                int64
# Store_Area              int64
# Items_Available         int64
# Daily_Customer_Count    int64
# Store_Sales             int64
# dtype: object

# %%
# An onverview of dataframe
Store_Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store ID              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
# statistical descriptive analysis of numerical features/variables.
Store_Sales.describe()
# Out:
#         Store ID    Store_Area  Items_Available  Daily_Customer_Count  \
# count  896.000000   896.000000       896.000000            896.000000
# mean   448.500000  1485.409598      1782.035714            786.350446
# std    258.797218   250.237011       299.872053            265.389281
# min      1.000000   775.000000       932.000000             10.000000
# 25%    224.750000  1316.750000      1575.500000            600.000000
# 50%    448.500000  1477.000000      1773.500000            780.000000
# 75%    672.250000  1653.500000      1982.750000            970.000000
# max    896.000000  2229.000000      2667.000000           1560.000000
#
#          Store_Sales
# count     896.000000
# mean    59351.305804
# std     17190.741895
# min     14920.000000
# 25%     46530.000000
# 50%     58605.000000
# 75%     71872.500000
# max    116320.000000

# %%
# To find out if there are duplicates
Store_Sales.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 891    False
# 892    False
# 893    False
# 894    False
# 895    False
# Length: 896, dtype: bool

# %% [markdown]
# ## Exploratory Data Analysis¶¶
# Creating relationship, insight and visualization of our dataset using
# ---- Univariante ---- Biavariante ---- Multivariante

# %%
Store_Sales.columns
# Out:
# Index(['Store ID ', 'Store_Area', 'Items_Available', 'Daily_Customer_Count',
#        'Store_Sales'],
#       dtype='object')

# %%
## To get the store with the largest area

largest_area_store = Store_Sales.loc[Store_Sales['Store_Area'].idxmax()]
print(largest_area_store)
# Out:
# Store ID                  467
# Store_Area               2229
# Items_Available          2667
# Daily_Customer_Count      660
# Store_Sales             87410
# Cluster                     2
# Name: 466, dtype: int64

# %%
## To get the store with the most daily customers

most_customers_store = Store_Sales.loc[Store_Sales['Daily_Customer_Count'].idxmax()]
print(most_customers_store)
# Out:
# Store ID                  849
# Store_Area                919
# Items_Available          1099
# Daily_Customer_Count     1560
# Store_Sales             73810
# Cluster                     2
# Name: 848, dtype: int64

# %%
# Histogram of Daily Customer Count

plt.figure(figsize=(10, 6))
sns.histplot(data=Store_Sales, x='Daily_Customer_Count', bins=20, kde=True)
plt.title('Histogram of Daily Customer Count')
plt.xlabel('Daily Customer Count')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Observation
# The resulting histogram shows the distribution of the Daily Customer Count.
# The x-axis represents the Daily Customer Count,
# and the y-axis represents the frequency (number of occurrences) of each interval (bin).
# The KDE curve provides a smooth estimate of the data's probability density function,
# allowing you to visualize the shape of the distribution more easily.

# %%
# Store Sales by store Area

Bar Plot of Top 10 Store Sales vs. Store Area

# Sort the data by Store_Sales in descending order and take the top 10 rows
top_10_sales = Store_Sales.sort_values(by='Store_Sales', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(data=top_10_sales, x='Store_Area', y='Store_Sales')
plt.title('Bar Plot of Top 10 Store Sales vs. Store Area')
plt.xlabel('Store Area')
plt.ylabel('Store Sales')
plt.show()

# %%
# Bar Plot of Bottom 10 Store Sales vs. Store Area

# Sort the data by Store_Sales in ascending order and take the bottom 10 rows
bottom_10_sales = Store_Sales.sort_values(by='Store_Sales', ascending=True).head(10)

# Sort the bottom 10 sales by Store_Sales for plotting
sorted_bottom_10_sales = bottom_10_sales.sort_values(by='Store_Sales', ascending=True)

plt.figure(figsize=(10, 6))
sns.barplot(data=sorted_bottom_10_sales, x='Store_Area', y='Store_Sales')
plt.title('Bar Plot of Bottom 10 Store Sales vs. Store Area')
plt.xlabel('Store Area')
plt.ylabel('Store Sales')
plt.show()

# %% [markdown]
# ## Observation
#
# To visualize the sales performance of the top 10 stores
# in terms of their sales and compare it with their respective store areas.

# %%
# Sales per square foot

Store_Sales['Sales_per_sqft'] = Store_Sales['Store_Sales'] / Store_Sales['Store_Area']
Store_Sales
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  \
# 0            1        1659             1961                   530
# 1            2        1461             1752                   210
# 2            3        1340             1609                   720
# 3            4        1451             1748                   620
# 4            5        1770             2111                   450
# ..         ...         ...              ...                   ...
# 891        892        1582             1910                  1080
# 892        893        1387             1663                   850
# 893        894        1200             1436                  1060
# 894        895        1299             1560                   770
# 895        896        1174             1429                  1110
#
#      Store_Sales  Sales_per_sqft
# 0          66490       40.078360
# 1          39820       27.255305
# 2          54010       40.305970
# 3          53730       37.029635
# ...

# %%
top_10_stores = Store_Sales_sorted.head(10)

plt.figure(figsize=(10, 6))
sns.barplot(data=top_10_stores, x='Store ID ', y='Sales_per_sqft', color='blue')
plt.title('Top 10 Stores: Sales per Square Foot')
plt.xlabel('Store ID')
plt.ylabel('Sales per Square Foot')
plt.xticks(rotation=90)
plt.show()

# %%
Store_Sales_sorted = Store_Sales.sort_values(by='Sales_per_sqft', ascending=False)
Store_Sales_sorted
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  \
# 556        557         932             1138                   820
# 468        469        1060             1279                   670
# 744        745         854             1018                   660
# 557        558        1137             1374                   700
# 339        340         966             1172                   900
# ..         ...         ...              ...                   ...
# 593        594        1624             1946                   870
# 31          32        1250             1508                   990
# 372        373        1876             2254                  1340
# 775        776        1537             1877                   660
# 852        853        1477             1790                   880
#
#      Store_Sales  Sales_per_sqft
# 556        89760       96.309013
# 468        97360       91.849057
# 744        77740       91.030445
# 557       101780       89.516271
# ...

# %% [markdown]
# ## Observation
# Store ID 557 had the highest value of 96.309013 sales per square

# %%
# Average daily sales
Store_Sales['Avg_Daily_Sales'] = Store_Sales['Store_Sales'] / Store_Sales['Daily_Customer_Count']
Store_Sales
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  \
# 0            1        1659             1961                   530
# 1            2        1461             1752                   210
# 2            3        1340             1609                   720
# 3            4        1451             1748                   620
# 4            5        1770             2111                   450
# ..         ...         ...              ...                   ...
# 891        892        1582             1910                  1080
# 892        893        1387             1663                   850
# 893        894        1200             1436                  1060
# 894        895        1299             1560                   770
# 895        896        1174             1429                  1110
#
#      Store_Sales  Sales_per_sqft  Avg_Daily_Sales
# 0          66490       40.078360       125.452830
# 1          39820       27.255305       189.619048
# ...

# %%
Store_Sales_sorted_by_avg_sales = Store_Sales.sort_values(by='Avg_Daily_Sales', ascending=False)
Store_Sales_sorted_by_avg_sales
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  \
# 39          40        1270             1516                    10
# 151        152        1662             1986                    70
# 876        877        1259             1493                   100
# 887        888        1156             1398                   140
# 230        231        1347             1628                   120
# ..         ...         ...              ...                   ...
# 223        224        1318             1606                  1200
# 852        853        1477             1790                   880
# 670        671        1461             1739                  1250
# 372        373        1876             2254                  1340
# 31          32        1250             1508                   990
#
#      Store_Sales  Sales_per_sqft  Avg_Daily_Sales
# 39         45480       35.811024      4548.000000
# 151        63730       38.345367       910.428571
# ...

# %% [markdown]
# # Observation
# Store ID 40 had the highest daily sales, followed by 152,877 respectively.

# %%
## Daily Customer Count vs. Sales Analysis


# Visualize the relationship between daily customer count and store sales

plt.figure(figsize=(10, 6))

sns.scatterplot(data=Store_Sales, x='Daily_Customer_Count', y='Store_Sales')

plt.title('Daily Customer Count vs. Store_Sales')

plt.xlabel('Daily Customer Count')

plt.ylabel('Store_Sales')

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.barplot(data=Store_Sales, x='Daily_Customer_Count', y='Store_Sales')

plt.title('Daily Customer Count vs. Store Sales')

plt.xlabel('Daily Customer Count')

plt.ylabel('Store Sales')

plt.show()

# %%
top_10_stores = Store_Sales.sort_values(by='Store_Sales', ascending=False).head(10)
Store_Sales
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
top_10_stores = Store_Sales.sort_values(by='Store_Sales', ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_stores, x='Store ID ', y='Store_Sales', palette='viridis')
plt.title('Top 10 Stores by Sales')
plt.xlabel('Store ID')
plt.ylabel('Store Sales')
plt.xticks(rotation=45)
plt.show()

# %%
top_10_stores = Store_Sales.sort_values(by='Store_Sales', ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_stores, x='Store ID ', y='Store_Sales', palette='viridis')
plt.title('Top 10 Stores by Sales')
plt.xlabel('Store ID')
plt.ylabel('Store Sales')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
top_items = Store_Sales['Items_Available'].value_counts().head(10)
top_items.plot(kind='bar')
plt.title('Top 10 Items Available Distribution')
plt.xlabel('Number of Items Available')
plt.ylabel('Frequency')
plt.show()

# %%
##  Items Available Distribution

top_5_items = Store_Sales['Items_Available'].value_counts().head(5)

plt.figure(figsize=(8, 8))
plt.pie(top_5_items, labels=top_5_items.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Items Available Distribution')
plt.show()

# %%
# Calculate the average store sales for each daily customer count

avg_sales = Store_Sales.groupby('Daily_Customer_Count')['Store_Sales'].mean().reset_index()
Store_Sales
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  \
# 0            1        1659             1961                   530
# 1            2        1461             1752                   210
# 2            3        1340             1609                   720
# 3            4        1451             1748                   620
# 4            5        1770             2111                   450
# ..         ...         ...              ...                   ...
# 891        892        1582             1910                  1080
# 892        893        1387             1663                   850
# 893        894        1200             1436                  1060
# 894        895        1299             1560                   770
# 895        896        1174             1429                  1110
#
#      Store_Sales  Cluster
# 0          66490        0
# 1          39820        1
# 2          54010        0
# 3          53730        0
# 4          46620        1
# ...

# %%
# Sort the dataframe by average store sales in descending order

avg_sales_sorted = avg_sales.sort_values('Store_Sales', ascending=False)
Store_Sales
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  \
# 0            1        1659             1961                   530
# 1            2        1461             1752                   210
# 2            3        1340             1609                   720
# 3            4        1451             1748                   620
# 4            5        1770             2111                   450
# ..         ...         ...              ...                   ...
# 891        892        1582             1910                  1080
# 892        893        1387             1663                   850
# 893        894        1200             1436                  1060
# 894        895        1299             1560                   770
# 895        896        1174             1429                  1110
#
#      Store_Sales  Cluster
# 0          66490        0
# 1          39820        1
# 2          54010        0
# 3          53730        0
# 4          46620        1
# ...

# %%
# Create a bar chart to display the top 5 daily customer counts by average store sales

plt.figure(figsize=(8, 4))

sns.barplot(data=avg_sales_sorted.head(5), x='Daily_Customer_Count', y='Store_Sales')

plt.title('Top 5 Daily Customer Counts by Average Store Sales')

plt.xlabel('Daily Customer Count')

plt.ylabel('Average Store Sales')

plt.show()
